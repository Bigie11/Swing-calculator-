# %% [markdown]
# <a href="https://colab.research.google.com/github/Bigie11/Swing-calculator-/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("nigeria_economic_data.csv")
df.head(5)
# Out:
#   Individual_ID  Age  Gender      Region Location Education_Level  \
# 0      8a61ea0b    6  Female  South East    Urban         Primary
# 1      dda4058f   46    Male  South West    Urban         Primary
# 2      a77f8728   50  Female  North West    Rural         Primary
# 3      77530bfc   64    Male  South East    Rural       Secondary
# 4      fdbccc7a    4    Male  North East    Rural             NaN
#
#        Occupation     Employment_Type  Monthly_Income_NGN  Poverty_Status
# 0         Student  Not in Labor Force                0.00               1
# 1  Trade/Services            Informal            35516.10               1
# 2     Agriculture            Informal            49952.97               1
# 3  Trade/Services       Self-employed            41902.41               1
# 4             NaN  Not in Labor Force                0.00               1

# %%
import pandas as pd

df = pd.read_csv("nigeria_nursing_mothers_healthcare.csv")
df.head(5)
# Out:
#   Geopolitical_Zone Residence Wealth_Quintile Education_Level  \
# 0        North East     Rural          Middle         Primary
# 1        South East     Urban         Richest          Higher
# 2     North Central     Urban          Richer         Primary
# 3     North Central     Rural         Poorest         Primary
# 4        North East     Urban          Richer       Secondary
#
#    Skilled_Birth_Attendance  Facility_Delivery  Exclusive_Breastfeeding  \
# 0                         1                  1                        1
# 1                         1                  1                        1
# 2                         1                  1                        0
# 3                         1                  1                        0
# 4                         1                  0                        1
#
#    Full_Immunization  Distance_to_Facility_km
# 0                  0                     9.35
# 1                  1                     1.99
# ...

# %%
import pandas as pd

df = pd.read_csv("nigeria_unemployment_missing_data.csv")
df.head(5)
# Out:
#    Age  Gender       Region Location Education_Level Employment_Status  \
# 0   53    Male   North West    Urban             NaN          Employed
# 1   43  Female   South West    Urban         Primary          Employed
# 2   29  Female  South South    Rural             NaN     Underemployed
# 3   57  Female   South West    Rural         Primary          Employed
# 4   22  Female  South South    Rural             NaN     Underemployed
#
#    Years_Of_Experience  Monthly_Income_NGN
# 0                 37.0            84220.84
# 1                 24.0            69911.72
# 2                  NaN            31096.21
# 3                 42.0           108994.91
# 4                  5.0            31807.56
